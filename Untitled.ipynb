# %% [markdown]
# <a href="https://colab.research.google.com/github/josedupre/josedupre.ase/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl

df1 = pd.read_excel('/content/Hogares_11.xlsx', sheet_name='Tabulado')
#df2 = pd.read_excel('/content/Migracion_01 (1).xlsx', sheet_name='Tabulado')

print(df1.columns)
# Out:
# Index(['Entidad federativa', 'Total', 'Ingreso del trabajo',
#        'Renta de la propiedad', 'Transferencias',
#        'Estimación del alquiler de la vivienda',
#        'Estimación del alquiler de la vivienda 2', 'Total.1',
#        'Sabe leer y escribir', 'No sabe leer y escribir', 'No especificado',
#        'Total viviendas particulares habitadas 2010',
#        'Total viviendas particulares habitadas 2020',
#        'Disponen de energía eléctrica 2010',
#        'Disponen de energía eléctrica 2020', 'Disponen de sanitario 2010',
#        'Disponen de sanitario 2020', 'Inmigrante 2010', 'Emigrante 2010',
#        'Saldo neto 2010', 'Inmigrante 2020', 'Emigrante 2020',
#        'Saldo neto 2020'],
#       dtype='object')

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Disponen de sanitario 2020')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Estimación del alquiler de la vivienda')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Transferencias')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Disponen de energía eléctrica 2020')
plt.show()

# %%
#@title
df1.plot(kind='bar', x='Entidad federativa', y='Disponen de sanitario 2020')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Disponen de sanitario 2010')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Disponen de energía eléctrica 2020')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Disponen de energía eléctrica 2010')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Total viviendas particulares habitadas 2020')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Total viviendas particulares habitadas 2010')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='No sabe leer y escribir')
plt.show()

# %%
df1 = pd.read_excel('/content/Hogares_11.xlsx')

df1.plot(kind='bar', x='Entidad federativa', y='Sabe leer y escribir')
plt.show()

# %%
df1 = pd.read_excel('/content/Hogares_11.xlsx')

df1.plot(kind='bar', x='Entidad federativa', y='Renta de la propiedad')
plt.show()

# %%
df1 = pd.read_excel('/content/Hogares_11.xlsx')

df1.plot(kind='bar', x='Entidad federativa', y='Estimación del alquiler de la vivienda 2')
plt.show()

# %%
df1 = pd.read_excel('/content/Hogares_11.xlsx')

df1.plot(kind='bar', x='Entidad federativa', y='Ingreso del trabajo')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Saldo neto 2010')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Saldo neto 2020')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Emigrante 2010')
plt.show()

# %%
df1.plot(kind='bar', x='Entidad federativa', y='Inmigrante 2010')
plt.show()

# %%
df2.plot(kind='bar', x='Entidad federativa', y='Inmigrante 2020')
plt.show()

# %%
df2.plot(kind='bar', x='Entidad federativa', y='Emigrante 2020')
plt.show()

# %%
fig, ax = plt.subplots()
df1.plot(kind='bar', x='Entidad federativa', y='Estimación del alquiler de la vivienda 2', color='blue', ax=ax)
df2.plot(kind='bar', x='Entidad federativa', y='Emigrante 2020', color='red', ax=ax)

plt.title('Título de la figura')
plt.xlabel('Etiqueta del eje x')
plt.ylabel('Etiqueta del eje y')

plt.show()

# %%
fig, ax = plt.subplots()
df1.plot(kind='bar', x='Entidad federativa', y='Saldo neto 2020', ax=ax, color='red', label='Datos 2020')
df1.plot(kind='bar', x='Entidad federativa', y='Saldo neto 2010', ax=ax, color='blue', label='Datos 2010')

ax.set_xlabel('Entidad federativa')
ax.set_ylabel('Emigrante 2020')
ax.set_title('Comparación de datos')

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


fig, ax = plt.subplots()

df1.plot(kind='bar', x='Entidad federativa', y='Saldo neto 2010', ax=ax, color='blue', label='Datos 2010')
df1.plot(kind='bar', x='Entidad federativa', y='Saldo neto 2020', ax=ax, color='red', label='Datos 2020')

ax.set_xlabel('Entidad federativa')
ax.set_ylabel('Emigrante 2020')
ax.set_title('Comparación de datos')

plt.legend()
plt.show()
